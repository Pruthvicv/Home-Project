# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/91965/Desktop/DATA SCIENCE/Project home/demand_data.csv")
df1.head()
# Out:
#          DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI
# 0  2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1  2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2  2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3  2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4  2001-01-01       4.23      7.01  13219.251          2.34  110.48

# %%
df2 = pd.read_csv("C:/Users/91965/Desktop/DATA SCIENCE/Project home/supply_data.csv")
df2.head()
# Out:
#    Unnamed: 0      Period  Permit_Number  construction  Homes_Sold  \
# 0           1  01-01-2000           1727        353065         873
# 1           2  01-02-2000           1692        351933         856
# 2           3  01-03-2000           1651        353452         900
# 3           4  01-04-2000           1597        356188         841
# 4           5  01-05-2000           1543        349907         857
#
#    Housing_Starts
# 0            1636
# 1            1737
# 2            1604
# 3            1626
# 4            1575

# %%
df1.shape,df2.shape
# Out:
# ((84, 6), (250, 6))

# %%
df_gdp = pd.read_csv("C:/Users/91965/Downloads/GDP.csv")
df_gdp.head()
# Out:
#          DATE        GDP
# 0  2003-04-01  11312.766
# 1  2003-07-01  11566.669
# 2  2003-10-01  11772.234
# 3  2004-01-01  11923.447
# 4  2004-04-01  12112.815

# %%
df_unemp = pd.read_csv("C:/Users/91965/Downloads/Unemployement RATE.csv")
df_unemp.head()
# Out:
#          DATE  UNRATE
# 0  2003-08-01     6.1
# 1  2003-09-01     6.1
# 2  2003-10-01     6.0
# 3  2003-11-01     5.8
# 4  2003-12-01     5.7

# %%
df_mortgage = pd.read_csv("C:/Users/91965/Downloads/MORTGAGE30US.csv")
df_mortgage.head()
# Out:
#          DATE  MORTGAGE30US
# 0  2003-09-19          6.01
# 1  2003-09-26          5.98
# 2  2003-10-03          5.77
# 3  2003-10-10          5.95
# 4  2003-10-17          6.05

# %%
df_realestateinterest = pd.read_csv("C:/Users/91965/Downloads/REAL estate INTerest RAte.csv")
df_realestateinterest.head()
# Out:
#          DATE  REAINTRATREARAT10Y
# 0  2003-09-01            1.897238
# 1  2003-10-01            1.380819
# 2  2003-11-01            1.713902
# 3  2003-12-01            1.713573
# 4  2004-01-01            1.701954

# %%
df_houseinventory = pd.read_csv("C:/Users/91965/Downloads/Housing inventory.csv")
df_houseinventory.head()
# Out:
#          DATE  ETOTALUSQ176N
# 0  2000-04-01       116047.0
# 1  2000-07-01       116482.0
# 2  2000-10-01       116914.0
# 3  2001-01-01       117347.0
# 4  2001-04-01       117786.0

# %%
df_price = pd.read_csv("C:/Users/91965/Downloads/CSUSHPISA (2).csv")
df_price.head()
# Out:
#          DATE  CSUSHPISA
# 0  2003-06-01    132.649
# 1  2003-07-01    133.777
# 2  2003-08-01    134.968
# 3  2003-09-01    136.294
# 4  2003-10-01    137.532

# %%
df_houseinventory['DATE'] = pd.to_datetime(df_houseinventory['DATE'])
df_mortgage['DATE'] = pd.to_datetime(df_mortgage['DATE'])
df_price['DATE'] = pd.to_datetime(df_price['DATE'])
df_realestateinterest['DATE'] = pd.to_datetime(df_realestateinterest['DATE'])
df_unemp['DATE'] = pd.to_datetime(df_unemp['DATE'])
df_gdp['DATE'] = pd.to_datetime(df_gdp['DATE'])

# %%
df1['DATE'] = pd.to_datetime(df1['DATE'])

# Convert "period" column in df2 to consistent date format
df2['Period'] = pd.to_datetime(df2['Period'], format='%d-%m-%Y').dt.strftime('%Y-%m-%d')
df2.rename(columns={'Period': 'DATE'}, inplace=True)
df2['DATE'] = pd.to_datetime(df2['DATE'])

# %%
dataset = pd.merge(df1,df2)
dataset
# Out:
#          DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  \
# 0  2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1  2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2  2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3  2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4  2001-01-01       4.23      7.01  13219.251          2.34  110.48
# ..        ...        ...       ...        ...           ...     ...
# 79 2019-10-01       3.60      3.70  19202.310          2.34  212.47
# 80 2020-01-01       3.80      3.52  18951.992          2.36  215.51
# 81 2020-04-01      13.07      3.24  17258.205          2.55  217.89
# 82 2020-07-01       8.80      2.95  18560.774          2.80  222.84
# 83 2020-10-01       6.77      2.76  18767.778          2.74  232.55
#
#     Unnamed: 0  Permit_Number  construction  Homes_Sold  Housing_Starts
# 0            1           1727        353065         873            1636
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for feature in dataset.columns:
    dataset.plot(feature)

# %%
import warnings
warnings.filterwarnings("ignore")
for feature in dataset.columns:
    plt.figure(figsize=(5,5))
    sns.distplot(dataset[feature])

# %%
for feature in dataset.columns:
    plt.figure(figsize=(3,3))
    plt.scatter(x=feature,y='HPI',data=dataset)
    plt.xlabel(feature)
    plt.ylabel("HPI")
    plt.title(feature,fontsize=10)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dataset.corr(),annot=True,cmap='Blues')
plt.show()

# %%
dataset.columns
# Out:
# Index(['DATE', 'UNEM_RATE', 'MORTGAGE', 'GDPC1', 'FORECLOSURES', 'HPI',
#        'Unnamed: 0', 'Permit_Number', 'construction', 'Homes_Sold',
#        'Housing_Starts'],
#       dtype='object')

# %%
dataset =dataset.drop('Unnamed: 0',axis=1)

# %%
dataset
# Out:
#          DATE  UNEM_RATE  MORTGAGE      GDPC1  FORECLOSURES     HPI  \
# 0  2000-01-01       4.03      8.26  12935.252          1.95  101.34
# 1  2000-04-01       3.93      8.32  13170.749          1.97  103.67
# 2  2000-07-01       4.00      8.02  13183.890          2.09  105.79
# 3  2000-10-01       3.90      7.62  13262.250          2.23  108.27
# 4  2001-01-01       4.23      7.01  13219.251          2.34  110.48
# ..        ...        ...       ...        ...           ...     ...
# 79 2019-10-01       3.60      3.70  19202.310          2.34  212.47
# 80 2020-01-01       3.80      3.52  18951.992          2.36  215.51
# 81 2020-04-01      13.07      3.24  17258.205          2.55  217.89
# 82 2020-07-01       8.80      2.95  18560.774          2.80  222.84
# 83 2020-10-01       6.77      2.76  18767.778          2.74  232.55
#
#     Permit_Number  construction  Homes_Sold  Housing_Starts
# 0            1727        353065         873            1636
# ...

# %%
numeric_values = [feature for feature in dataset.columns if dataset[feature].dtype == 'float']

# %%
for feature in numeric_values:
    data=dataset.copy()  
    data.boxplot(column=feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()
    plt.figure(figsize=(5,5))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X=dataset.drop(['HPI','DATE'],axis=1)
y=dataset['HPI']

# %%
#spliting our dependent and independent features
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (58, 8)
# (26, 8)

# %%
#using a minmaxScaler
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
scaled_X_train= pd.DataFrame(minmax.fit_transform(X_train),columns=X_train.columns)
scaled_X_test=pd.DataFrame(minmax.transform(X_test),columns=X_test.columns)

# %%
#Linear regression model
my_pipeline = Pipeline(steps=[('preprocessor', SimpleImputer()),
                              ('model', LinearRegression())
                             ])


scores = -1 * cross_val_score(my_pipeline, X_train, y_train,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("MAE scores:\n", scores)
# Out:
# MAE scores:
#  [3.85357158 4.08704755 4.64791962 4.09130873 4.30745722]

# %%
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.9695848812675697

# %%
#RandomForestRegressor model
my_pipeline = Pipeline(steps=[('preprocessor', SimpleImputer()),
                              ('model', RandomForestRegressor())
                             ])


scores = -1 * cross_val_score(my_pipeline, X_train, y_train,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("MAE scores:\n", scores)
# Out:
# MAE scores:
#  [5.30805833 3.03803333 4.996125   2.15584545 2.69226364]

# %%
model=RandomForestRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8577608208683587

# %%
#GradientBoostingRegressor model
my_pipeline = Pipeline(steps=[('preprocessor', SimpleImputer()),
                              ('model', GradientBoostingRegressor())
                             ])


scores = -1 * cross_val_score(my_pipeline, X_train, y_train,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("MAE scores:\n", scores)
# Out:
# MAE scores:
#  [6.33786435 1.66723856 5.64313274 2.17968412 2.12539394]

# %%
model=GradientBoostingRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.9584734984006188

# %%
plt.figure(figsize=(5,5))
plt.scatter(y_test,y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(y_pred), max(y_test))
p2 = min(min(y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()
